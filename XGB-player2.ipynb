# %% [markdown]
# # Notebook for building an XGBoost model for the Sendgrid sign up dataset
# ***
# **Jake Mitchell Scott Schubert**
#
# Initially using ______

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from random import randint
from datetime import datetime
# Out:
# C:\Users\jakem\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train_path = 'data/signup_train_data.csv'
test_path = 'data/signup_test_data.csv'


# Load the data into a DataFrame 
df = pd.read_csv(train_path, low_memory=False)
test_df = pd.read_csv(test_path, low_memory=False)

# Split into X and Y
dfLabels = df.pop("label")
#print (df.head())

#Feature Engineering
#for index, row in df.iterrows():
#    df['time_of_day_int'] = introw['created_at'][11:13])*3600 + int(row['created_at'][14:16])*60 + int(row['created_at'][17:19])


#Temporarily parse non numerical data
frames_to_remove = ['zip', 'city', 'website', 'state', 'country', 'registration_ip', 'company','multifactor_country_code','created_at','lead_source','marketing_channel','volume','user_persona','initial_package','employee_count','geolocation_notes','name_notes','ip_notes','community_notes','email_notes','activity_notes','fingerprint_notes']
df = df.drop(frames_to_remove, axis=1)
test_df = test_df.drop(frames_to_remove, axis=1)

dfTest.head()
# Out:
#    id                  website         city state  zip country  \
# 0   0     http://tvtropes.org/     Manassas    VA  NaN      US
# 1   1       http://memebau.com        Tulsa    OK  NaN      US
# 2   2  http:/www./ShellsFor.Me        Ajman    AJ  NaN      AE
# 3   3          www.hjhj.com.mx  Mexico City   CMX  NaN      MX
# 4   4                jk.edu.br     Brasília    DF  NaN      BR
#
#    registration_ip  banned_ip  ip_count      company       ...         \
# 0     207.244.77.8          6         8    tvtropes        ...
# 1   104.168.149.15          5         5     memekbau       ...
# 2  109.177.112.218          0         1  ShellsForMe       ...
# 3   201.137.247.62          4         4           bb       ...
# 4  179.176.123.238          0         1           jk       ...
#
#   ip_cluster  email_cluster  mfa_required  mfa_completed whitelabel_required  \
# 0      False          False           1.0            0.0                 1.0
# 1      False          False           NaN            NaN                 NaN
# 2      False          False           NaN            NaN                 NaN
# 3      False          False           1.0            0.0                 1.0
# 4      False          False           NaN            NaN                 NaN
#
#   whitelabel_completed payment_required payment_completed  profile_completed  \
# 0                  0.0              0.0               0.0                1.0
# 1                  NaN              NaN               NaN                NaN
# 2                  NaN              NaN               NaN                NaN
# 3                  0.0              0.0               0.0                1.0
# 4                  NaN              NaN               NaN                NaN
#
#    email_completed
# 0              0.0
# 1              NaN
# 2              NaN
# 3              0.0
# 4              NaN
#
# [5 rows x 49 columns]

# %%
def xgb_basic(seed_in, TO_TEST, eta=0.1, max_depth=3):
    # split data into train and test sets
    seed = seed_in
    test_size = 0.5
    X_train, X_test, y_train, y_test = train_test_split(df, dfLabels, test_size=test_size, random_state=seed)

    # fit model no training data
    model = XGBClassifier(learning_rate=eta, max_depth=max_depth)
    model.fit(X_train, y_train)
    
    # make predictions for test data
    y_pred = model.predict(X_test)
    predictions = [round(value) for value in y_pred]

    # evaluate predictions
    accuracy = accuracy_score(y_test, predictions)
    print("Seed: %i Eta: %f   -  Accuracy: %.2f%%" % (seed,eta, accuracy * 100.0))
    
    if TO_TEST:
        #make predictions for train data
        y_pred = model.predict(test_df)
        predictions = [round(value) for value in y_pred]

        d = {'id':test_df['id'], 'label':predictions}
        preds = pd.DataFrame(data=d)

        preds.to_csv('predictions.csv', index=False)

# %%
#for i in [randint(0,50) for a in range(3)]:
xgb_basic(i,True, max_depth=15)

#for x in range (15,100):
#    xgb_basic(x, False)
# Out:
# Seed: 31 Eta: 0.100000   -  Accuracy: 97.30%

# %%
28, 31
